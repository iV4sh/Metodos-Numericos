# %% [markdown]
# # **Ejercicio 0-1 Notebook** 📝
#
# * Python
# * GitHub

# %% [markdown]
# ### **Enlaces de Interes**
#
# * https://github.com/iV4sh/Metodos-Numericos.git
# * https://gitmoji.dev
#
# ---

# %% [markdown]
# ### **Graficar Funciones**
# $y(x) = x^3 - 7x^2 + 4x + 12$
#
# * **Tabla de valores**
#
# | i   | x   | y   |
# |-------------|-------------|-------------|
# | 0    | -5    | -308    |
# | 1    | 0    | 12    |
# | 2    | 5    | -18    |

# %%
# Definición de la ecuación
def eqn(x):
    return x**3 - 7 * x**2 + 4 * x + 12

# %%
# Generador de puntos para la gráfica
import numpy as np

## Generar 100 datos del -10 al 10
Xs, step = np.linspace(-10, 10,num=100, retstep=True)

# %%
# Generador de valores
Ys = []

for x in Xs:
    y = eqn(x)
    Ys.append(y)
    print(f"x = {x:.2f} \t y = {y:.2f}")
# Out:
# x = -10.00 	 y = -1728.00
# x = -9.80 	 y = -1639.80
# x = -9.60 	 y = -1554.58
# x = -9.39 	 y = -1472.28
# x = -9.19 	 y = -1392.85
# x = -8.99 	 y = -1316.24
# x = -8.79 	 y = -1242.40
# x = -8.59 	 y = -1171.29
# x = -8.38 	 y = -1102.85
# x = -8.18 	 y = -1037.03
# x = -7.98 	 y = -973.79
# x = -7.78 	 y = -913.08
# x = -7.58 	 y = -854.84
# x = -7.37 	 y = -799.02
# x = -7.17 	 y = -745.59
# x = -6.97 	 y = -694.48
# x = -6.77 	 y = -645.65
# x = -6.57 	 y = -599.05
# x = -6.36 	 y = -554.63
# x = -6.16 	 y = -512.33
# x = -5.96 	 y = -472.12
# x = -5.76 	 y = -433.94
# x = -5.56 	 y = -397.74
# x = -5.35 	 y = -363.47
# x = -5.15 	 y = -331.08
# x = -4.95 	 y = -300.53
# x = -4.75 	 y = -271.76
# x = -4.55 	 y = -244.72
# x = -4.34 	 y = -219.37
# x = -4.14 	 y = -195.66
# x = -3.94 	 y = -173.52
# x = -3.74 	 y = -152.93
# x = -3.54 	 y = -133.82
# x = -3.33 	 y = -116.15
# x = -3.13 	 y = -99.86
# x = -2.93 	 y = -84.92
# x = -2.73 	 y = -71.26
# x = -2.53 	 y = -58.84
# ...

# %%
from matplotlib import pyplot as plt
# Alternative: import seaborn as sns
plt.plot(Xs, Ys, marker=".",linestyle=":")
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title("Grafica de la función cúbica")
plt.grid()
plt.legend(["$y(x) = x^3 - 7x^2 + 4x + 12$"])


## Tarea hacer zoom

plt.xlim(-5, 8)  # Zoom en el eje x
plt.ylim(-25, 20) # Zoom en el eje y

plt.show()
